# %%
#Script context use	: This script uses Raymotime data (https://www.lasse.ufpa.br/raymobtime/) in the context of the UFPA - ITU Artificial Intelligence/Machine Learning in 5G Challenge (http://ai5gchallenge.ufpa.br/).
#Author       		: Ailton Oliveira, Aldebaro Klautau, Arthur Nascimento, Diego Gomes, Jamelly Ferreira, Walter Frazao
#Email          	: ml5gphy@gmail.com                                          
#License		: This script is distributed under "Public Domain" license.
###################################################################

#!/usr/bin/env python3
# -*- coding: utf-8 -*-

'''Trains a deep NN for choosing top-K beams
Adapted by AK: Aug 7, 2018
See
https://machinelearningmastery.com/binary-classification-tutorial-with-the-keras-deep-learning-library/
and
https://stackoverflow.com/questions/45642077/do-i-need-to-use-one-hot-encoding-if-my-output-variable-is-binary
See for explanation about convnet and filters:
https://datascience.stackexchange.com/questions/16463/what-is-are-the-default-filters-used-by-keras-convolution2d
and
http://cs231n.github.io/convolutional-networks/
'''
from google.colab import drive
drive.mount('/content/drive/')
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks')

import csv
import tensorflow as tf
from tensorflow.keras import metrics
from tensorflow.keras.models import model_from_json,Model
from tensorflow.keras.layers import Dense,concatenate
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adadelta,Adam
from sklearn.model_selection import train_test_split
from ModelHandler import ModelHandler
import numpy as np
import argparse


###############################################################################
# Support functions
###############################################################################

#For description about top-k, including the explanation on how they treat ties (which can be misleading
#if your classifier is outputting a lot of ties (e.g. all 0's will lead to high top-k)
#https://www.tensorflow.org/api_docs/python/tf/nn/in_top_k
def top_10_accuracy(y_true,y_pred):
    return metrics.top_k_categorical_accuracy(y_true,y_pred,k=10)

def top_30_accuracy(y_true, y_pred):
    return metrics.top_k_categorical_accuracy(y_true, y_pred, k=30)

def top_50_accuracy(y_true,y_pred):
    return metrics.top_k_categorical_accuracy(y_true,y_pred,k=50)

def top_100_accuracy(y_true, y_pred):
    return metrics.top_k_categorical_accuracy(y_true, y_pred, k=100)


def sub2ind(array_shape, rows, cols):
    ind = rows*array_shape[1] + cols
    ind[ind < 0] = -1
    ind[ind >= array_shape[0]*array_shape[1]] = -1
    return ind

def ind2sub(array_shape, ind):
    ind[ind < 0] = -1
    ind[ind >= array_shape[0]*array_shape[1]] = -1
    rows = (ind.astype('int') / array_shape[1])
    cols = ind % array_shape[1]
    return (rows, cols)

def beamsLogScale(y,thresholdBelowMax):
        y_shape = y.shape
        
        for i in range(0,y_shape[0]):            
            thisOutputs = y[i,:]
            logOut = 20*np.log10(thisOutputs + 1e-30)
            minValue = np.amax(logOut) - thresholdBelowMax
            zeroedValueIndices = logOut < minValue
            thisOutputs[zeroedValueIndices]=0
            thisOutputs = thisOutputs / sum(thisOutputs)
            y[i,:] = thisOutputs
        
        return y

def getBeamOutput(output_file):
    
    thresholdBelowMax = 6
    
    print("Reading dataset...", output_file)
    output_cache_file = np.load(output_file)
    yMatrix = output_cache_file['output_classification']
    
    yMatrix = np.abs(yMatrix)
    yMatrix /= np.max(yMatrix)
    yMatrixShape = yMatrix.shape
    num_classes = yMatrix.shape[1] * yMatrix.shape[2]
    
    y = yMatrix.reshape(yMatrix.shape[0],num_classes)
    y = beamsLogScale(y,thresholdBelowMax)
    
    return y,num_classes

###############################################################################
# Data configuration
###############################################################################
tf.device('/device:GPU:0')

coord = False
img = False
lidar = True

num_epochs = 30
batch_size = 32
tgtRec = 3
seed = 7

np.random.seed(seed)

if coord == True: 
    ###############################################################################
    # Coordinate configuration
    #train
    coord_train_input_file = '/content/drive/MyDrive/ssp_data/baseline_data/coord_input/coord_input.npz'
    coord_train_cache_file = np.load(coord_train_input_file)
    X_coord = coord_train_cache_file['coordinates']
    X_coord_train, X_coord_validation = train_test_split(X_coord, test_size=0.2, random_state=seed, shuffle=True)

    coord_train_input_shape = X_coord_train.shape

if img == True:
    ###############################################################################
    # Image configuration
    resizeFac = 20 # Resize Factor
    nCh = 1 # The number of channels of the image
    imgDim = (360,640) # Image dimensions
    method = 1

    #train
    img_train_input_file = '/content/drive/MyDrive/ssp_data/baseline_data/image_input/img_input_20.npz'
    img_train_cache_file = np.load(img_train_input_file)
    X_img = img_train_cache_file['inputs']
    X_img_train, X_img_validation = train_test_split(X_img, test_size=0.2, random_state=seed, shuffle=True)
    print("Reading dataset... ",img_train_input_file)

    img_train_input_shape = X_img_train.shape

if lidar == True:
    ###############################################################################
    # LIDAR configuration
    #train
    #lidar_train_input_file = data_dir+'image_input/img_input_train_'+str(resizeFac)+'.npz'
    lidar_train_input_file = '/content/drive/MyDrive/ssp_data/baseline_data/lidar_input/lidar_input.npz'
    lidar_train_cache_file = np.load(lidar_train_input_file)
    X_lidar = lidar_train_cache_file['input']
    X_lidar_train, X_lidar_validation = train_test_split(X_lidar, test_size=0.2, random_state=seed, shuffle=True)
    print("Reading dataset... ",lidar_train_input_file)
    lidar_train_input_shape = X_lidar_train.shape

###############################################################################
# Output configuration
#train
output_file = '/content/drive/MyDrive/ssp_data/baseline_data/beam_output/beams_output.npz'
y_output,num_classes = getBeamOutput(output_file)
y_train, y_validation = train_test_split(y_output, test_size=0.2, random_state=seed, shuffle=True)
#output_validation_file = data_dir+'beam_output/beams_output_validation.npz'
#y_validation, _ = getBeamOutput(output_validation_file)

##############################################################################
# Model configuration
##############################################################################

#multimodal
multimodal = [coord, img, lidar]

#validationFraction = 0.2 #from 0 to 1
modelHand = ModelHandler()
opt = Adam()

if coord:
    coord_model = modelHand.createArchitecture('coord_mlp',num_classes,coord_train_input_shape[1],'complete')
if img:
    if nCh==1:   
        img_model = modelHand.createArchitecture('light_image',num_classes,[img_train_input_shape[1],img_train_input_shape[2],1],'complete')
    else:
        img_model = modelHand.createArchitecture('light_image',num_classes,[img_train_input_shape[1],img_train_input_shape[2],img_train_input_shape[3]],'complete')
if lidar:
    lidar_model = modelHand.createArchitecture('lidar_marcus',num_classes,[lidar_train_input_shape[1],lidar_train_input_shape[2],lidar_train_input_shape[3]],'complete')

if sum(multimodal) == 2:
    if coord and lidar:
        combined_model = concatenate([coord_model.output,lidar_model.output])
        z = Dense(num_classes,activation="relu")(combined_model)
        model = Model(inputs=[coord_model.input,lidar_model.input],outputs=z)
        model.compile(loss=categorical_crossentropy,
                    optimizer=opt,
                    metrics=[metrics.categorical_accuracy,
                            metrics.top_k_categorical_accuracy,
                            top_10_accuracy,
                            top_30_accuracy,
                            top_50_accuracy,
                            top_100_accuracy])
        model.summary()
        hist = model.fit([X_coord_train,X_lidar_train],y_train, 
        validation_data=([X_coord_validation, X_lidar_validation], y_validation),epochs=num_epochs,batch_size=batch_size)

    elif coord and img:
        combined_model = concatenate([coord_model.output,img_model.output])
        z = Dense(num_classes,activation="relu")(combined_model)
        model = Model(inputs=[coord_model.input,img_model.input],outputs=z)
        model.compile(loss=categorical_crossentropy,
                    optimizer=opt,
                    metrics=[metrics.categorical_accuracy,
                            metrics.top_k_categorical_accuracy,
                            top_10_accuracy,
                            top_30_accuracy,
                            top_50_accuracy,
                            top_100_accuracy])
        model.summary()
        hist = model.fit([X_coord_train,X_img_train],y_train,
        validation_data=([X_coord_validation, X_img_validation], y_validation), epochs=num_epochs,batch_size=batch_size)
    
    else:
        combined_model = concatenate([lidar_model.output,img_model.output])
        z = Dense(num_classes,activation="relu")(combined_model)
        model = Model(inputs=[lidar_model.input,img_model.input],outputs=z)
        model.compile(loss=categorical_crossentropy,
                    optimizer=opt,
                    metrics=[metrics.categorical_accuracy,
                            metrics.top_k_categorical_accuracy,
                            top_10_accuracy,
                            top_30_accuracy,
                            top_50_accuracy,
                            top_100_accuracy])
        model.summary()
        hist = model.fit([X_lidar_train,X_img_train],y_train, 
        validation_data=([X_lidar_validation, X_img_validation], y_validation), epochs=num_epochs,batch_size=batch_size)
elif sum(multimodal) == 3:
    combined_model = concatenate([lidar_model.output,img_model.output, coord_model.output])
    z = Dense(num_classes,activation="relu")(combined_model)
    model = Model(inputs=[lidar_model.input,img_model.input, coord_model.input],outputs=z)
    model.compile(loss=categorical_crossentropy,
                optimizer=opt,
                metrics=[metrics.categorical_accuracy,
                        metrics.top_k_categorical_accuracy,
                        top_10_accuracy,
                        top_30_accuracy,
                        top_50_accuracy,
                        top_100_accuracy])
    model.summary()
    hist = model.fit([X_lidar_train,X_img_train,X_coord_train],y_train,
            validation_data=([X_lidar_validation, X_img_validation, X_coord_validation], y_validation),
            epochs=num_epochs,batch_size=batch_size)

else:
    if coord:
        model = coord_model
        model.compile(loss=categorical_crossentropy,
                            optimizer=opt,
                            metrics=[metrics.categorical_accuracy,
                                    metrics.top_k_categorical_accuracy,
                                    top_10_accuracy,
                                    top_30_accuracy, 
                                    top_50_accuracy,
                                    top_100_accuracy])
        model.summary()
        hist = model.fit(X_coord_train,y_train, 
        validation_data=(X_coord_validation, y_validation),epochs=num_epochs,batch_size=batch_size)

    elif img:
        model = img_model  
        model.compile(loss=categorical_crossentropy,
                    optimizer=opt,
                    metrics=[metrics.categorical_accuracy,
                            metrics.top_k_categorical_accuracy,
                            top_10_accuracy,
                            top_30_accuracy,
                            top_50_accuracy,
                            top_100_accuracy])
        model.summary()
        hist = model.fit(X_img_train,y_train, 
        validation_data=(X_img_validation, y_validation),epochs=num_epochs,batch_size=batch_size)

    else:
        model = lidar_model
        model.compile(loss=categorical_crossentropy,
                    optimizer=opt,
                    metrics=[metrics.categorical_accuracy,
                            metrics.top_k_categorical_accuracy,
                            top_10_accuracy,
                            top_30_accuracy,
                            top_50_accuracy,
                            top_100_accuracy])
        model.summary()
        hist = model.fit(X_lidar_train,y_train, 
        validation_data=(X_lidar_validation, y_validation),epochs=num_epochs,batch_size=batch_size)

if False:
    import matplotlib.pyplot as plt


    import matplotlib     
    matplotlib.rcParams.update({'font.size': 15})
    fileNameIdentifier = '/content/drive/MyDrive/ssp_data/baseline_data/obstacles'
    f = open(fileNameIdentifier + '.txt','w')
    f.write(str(hist.history))
    f.close()

    acc = hist.history['top_k_categorical_accuracy']
    val_acc = hist.history['val_top_k_categorical_accuracy']

    loss = hist.history['loss']
    val_loss = hist.history['val_loss']
    epochs = range(1, len(acc)+1)
    
    plt.subplot(121)
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.plot(epochs, acc, 'b--', label='accuracy', linewidth=2)
    plt.plot(epochs, val_acc, 'g-', label='validation accuracy',linewidth=2)
    plt.legend()
    plt.subplot(122)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.plot(epochs, loss, 'b--', label='loss',linewidth=2)
    plt.plot(epochs, val_loss, 'g--', label='validation loss',linewidth=2)
    plt.legend()

    plt.show()
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# Reading dataset...  /content/drive/MyDrive/ssp_data/baseline_data/lidar_input/lidar_input.npz
# Reading dataset... /content/drive/MyDrive/ssp_data/baseline_data/beam_output/beams_output.npz
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 20, 200, 10)]     0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 20, 200, 10)       16910
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 20, 200, 30)       36330
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 20, 200, 25)       60775
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 10, 200, 25)       0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 10, 200, 25)       0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 10, 200, 20)       24520
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 10, 100, 20)       0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 10, 100, 15)       7515
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 10, 100, 15)       0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 10, 100, 10)       1360
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 10, 100, 1)        11
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1000)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               256256
# =================================================================
# Total params: 403,677
# Trainable params: 403,677
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 280/280 [==============================] - 11s 35ms/step - loss: 3.4780 - categorical_accuracy: 0.1996 - top_k_categorical_accuracy: 0.5373 - top_10_accuracy: 0.6861 - top_30_accuracy: 0.8729 - top_50_accuracy: 0.9202 - top_100_accuracy: 0.9540 - val_loss: 2.7587 - val_categorical_accuracy: 0.2948 - val_top_k_categorical_accuracy: 0.6807 - val_top_10_accuracy: 0.8146 - val_top_30_accuracy: 0.9616 - val_top_50_accuracy: 0.9830 - val_top_100_accuracy: 0.9946
# Epoch 2/30
# 280/280 [==============================] - 10s 34ms/step - loss: 2.5648 - categorical_accuracy: 0.3289 - top_k_categorical_accuracy: 0.7344 - top_10_accuracy: 0.8549 - top_30_accuracy: 0.9716 - top_50_accuracy: 0.9903 - top_100_accuracy: 0.9992 - val_loss: 2.5360 - val_categorical_accuracy: 0.3560 - val_top_k_categorical_accuracy: 0.7285 - val_top_10_accuracy: 0.8495 - val_top_30_accuracy: 0.9687 - val_top_50_accuracy: 0.9862 - val_top_100_accuracy: 0.9973
# Epoch 3/30
# 280/280 [==============================] - 10s 35ms/step - loss: 2.3171 - categorical_accuracy: 0.3896 - top_k_categorical_accuracy: 0.7772 - top_10_accuracy: 0.8803 - top_30_accuracy: 0.9773 - top_50_accuracy: 0.9931 - top_100_accuracy: 1.0000 - val_loss: 2.3642 - val_categorical_accuracy: 0.4046 - val_top_k_categorical_accuracy: 0.7669 - val_top_10_accuracy: 0.8607 - val_top_30_accuracy: 0.9723 - val_top_50_accuracy: 0.9879 - val_top_100_accuracy: 0.9987
# Epoch 4/30
# 280/280 [==============================] - 10s 35ms/step - loss: 2.1267 - categorical_accuracy: 0.4387 - top_k_categorical_accuracy: 0.8223 - top_10_accuracy: 0.9109 - top_30_accuracy: 0.9838 - top_50_accuracy: 0.9966 - top_100_accuracy: 0.9998 - val_loss: 2.2974 - val_categorical_accuracy: 0.4346 - val_top_k_categorical_accuracy: 0.7820 - val_top_10_accuracy: 0.8727 - val_top_30_accuracy: 0.9714 - val_top_50_accuracy: 0.9893 - val_top_100_accuracy: 0.9982
# Epoch 5/30
# 280/280 [==============================] - 10s 36ms/step - loss: 2.0441 - categorical_accuracy: 0.4671 - top_k_categorical_accuracy: 0.8395 - top_10_accuracy: 0.9214 - top_30_accuracy: 0.9867 - top_50_accuracy: 0.9972 - top_100_accuracy: 1.0000 - val_loss: 2.2261 - val_categorical_accuracy: 0.4538 - val_top_k_categorical_accuracy: 0.7968 - val_top_10_accuracy: 0.8781 - val_top_30_accuracy: 0.9763 - val_top_50_accuracy: 0.9875 - val_top_100_accuracy: 0.9973
# Epoch 6/30
# 280/280 [==============================] - 10s 36ms/step - loss: 1.9174 - categorical_accuracy: 0.5119 - top_k_categorical_accuracy: 0.8534 - top_10_accuracy: 0.9263 - top_30_accuracy: 0.9914 - top_50_accuracy: 0.9975 - top_100_accuracy: 1.0000 - val_loss: 2.2167 - val_categorical_accuracy: 0.4547 - val_top_k_categorical_accuracy: 0.7977 - val_top_10_accuracy: 0.8749 - val_top_30_accuracy: 0.9728 - val_top_50_accuracy: 0.9906 - val_top_100_accuracy: 0.9987
# Epoch 7/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.8522 - categorical_accuracy: 0.5176 - top_k_categorical_accuracy: 0.8640 - top_10_accuracy: 0.9377 - top_30_accuracy: 0.9945 - top_50_accuracy: 0.9988 - top_100_accuracy: 1.0000 - val_loss: 2.1882 - val_categorical_accuracy: 0.4806 - val_top_k_categorical_accuracy: 0.8021 - val_top_10_accuracy: 0.8816 - val_top_30_accuracy: 0.9736 - val_top_50_accuracy: 0.9888 - val_top_100_accuracy: 0.9978
# Epoch 8/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.8054 - categorical_accuracy: 0.5390 - top_k_categorical_accuracy: 0.8763 - top_10_accuracy: 0.9443 - top_30_accuracy: 0.9943 - top_50_accuracy: 0.9993 - top_100_accuracy: 1.0000 - val_loss: 2.1794 - val_categorical_accuracy: 0.4761 - val_top_k_categorical_accuracy: 0.8026 - val_top_10_accuracy: 0.8892 - val_top_30_accuracy: 0.9750 - val_top_50_accuracy: 0.9884 - val_top_100_accuracy: 0.9987
# Epoch 9/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.7406 - categorical_accuracy: 0.5445 - top_k_categorical_accuracy: 0.8779 - top_10_accuracy: 0.9515 - top_30_accuracy: 0.9969 - top_50_accuracy: 0.9994 - top_100_accuracy: 1.0000 - val_loss: 2.1893 - val_categorical_accuracy: 0.4837 - val_top_k_categorical_accuracy: 0.8021 - val_top_10_accuracy: 0.8892 - val_top_30_accuracy: 0.9745 - val_top_50_accuracy: 0.9897 - val_top_100_accuracy: 0.9987
# Epoch 10/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.6822 - categorical_accuracy: 0.5635 - top_k_categorical_accuracy: 0.8944 - top_10_accuracy: 0.9589 - top_30_accuracy: 0.9966 - top_50_accuracy: 0.9995 - top_100_accuracy: 1.0000 - val_loss: 2.1984 - val_categorical_accuracy: 0.4676 - val_top_k_categorical_accuracy: 0.8084 - val_top_10_accuracy: 0.8910 - val_top_30_accuracy: 0.9768 - val_top_50_accuracy: 0.9888 - val_top_100_accuracy: 0.9987
# Epoch 11/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.6367 - categorical_accuracy: 0.5730 - top_k_categorical_accuracy: 0.9005 - top_10_accuracy: 0.9607 - top_30_accuracy: 0.9969 - top_50_accuracy: 0.9992 - top_100_accuracy: 1.0000 - val_loss: 2.1788 - val_categorical_accuracy: 0.4649 - val_top_k_categorical_accuracy: 0.8129 - val_top_10_accuracy: 0.8906 - val_top_30_accuracy: 0.9768 - val_top_50_accuracy: 0.9906 - val_top_100_accuracy: 0.9982
# Epoch 12/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.6037 - categorical_accuracy: 0.5840 - top_k_categorical_accuracy: 0.9112 - top_10_accuracy: 0.9656 - top_30_accuracy: 0.9979 - top_50_accuracy: 0.9999 - top_100_accuracy: 1.0000 - val_loss: 2.1929 - val_categorical_accuracy: 0.4868 - val_top_k_categorical_accuracy: 0.8026 - val_top_10_accuracy: 0.8874 - val_top_30_accuracy: 0.9763 - val_top_50_accuracy: 0.9906 - val_top_100_accuracy: 0.9973
# Epoch 13/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.5483 - categorical_accuracy: 0.5932 - top_k_categorical_accuracy: 0.9165 - top_10_accuracy: 0.9701 - top_30_accuracy: 0.9991 - top_50_accuracy: 0.9996 - top_100_accuracy: 1.0000 - val_loss: 2.2636 - val_categorical_accuracy: 0.4761 - val_top_k_categorical_accuracy: 0.8102 - val_top_10_accuracy: 0.8870 - val_top_30_accuracy: 0.9745 - val_top_50_accuracy: 0.9902 - val_top_100_accuracy: 0.9982
# Epoch 14/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.4967 - categorical_accuracy: 0.6002 - top_k_categorical_accuracy: 0.9267 - top_10_accuracy: 0.9774 - top_30_accuracy: 0.9987 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.2283 - val_categorical_accuracy: 0.4730 - val_top_k_categorical_accuracy: 0.8008 - val_top_10_accuracy: 0.8852 - val_top_30_accuracy: 0.9714 - val_top_50_accuracy: 0.9884 - val_top_100_accuracy: 0.9973
# Epoch 15/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.4815 - categorical_accuracy: 0.6041 - top_k_categorical_accuracy: 0.9253 - top_10_accuracy: 0.9766 - top_30_accuracy: 0.9980 - top_50_accuracy: 0.9999 - top_100_accuracy: 1.0000 - val_loss: 2.3422 - val_categorical_accuracy: 0.4600 - val_top_k_categorical_accuracy: 0.7999 - val_top_10_accuracy: 0.8897 - val_top_30_accuracy: 0.9754 - val_top_50_accuracy: 0.9902 - val_top_100_accuracy: 0.9969
# Epoch 16/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.4185 - categorical_accuracy: 0.6186 - top_k_categorical_accuracy: 0.9376 - top_10_accuracy: 0.9819 - top_30_accuracy: 0.9996 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.2703 - val_categorical_accuracy: 0.4614 - val_top_k_categorical_accuracy: 0.7977 - val_top_10_accuracy: 0.8816 - val_top_30_accuracy: 0.9745 - val_top_50_accuracy: 0.9897 - val_top_100_accuracy: 0.9973
# Epoch 17/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.3926 - categorical_accuracy: 0.6213 - top_k_categorical_accuracy: 0.9425 - top_10_accuracy: 0.9843 - top_30_accuracy: 0.9997 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.2335 - val_categorical_accuracy: 0.4609 - val_top_k_categorical_accuracy: 0.7950 - val_top_10_accuracy: 0.8803 - val_top_30_accuracy: 0.9723 - val_top_50_accuracy: 0.9884 - val_top_100_accuracy: 0.9978
# Epoch 18/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.3574 - categorical_accuracy: 0.6274 - top_k_categorical_accuracy: 0.9501 - top_10_accuracy: 0.9858 - top_30_accuracy: 0.9996 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.2780 - val_categorical_accuracy: 0.4600 - val_top_k_categorical_accuracy: 0.7843 - val_top_10_accuracy: 0.8781 - val_top_30_accuracy: 0.9714 - val_top_50_accuracy: 0.9866 - val_top_100_accuracy: 0.9964
# Epoch 19/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.3306 - categorical_accuracy: 0.6453 - top_k_categorical_accuracy: 0.9501 - top_10_accuracy: 0.9866 - top_30_accuracy: 0.9994 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.3580 - val_categorical_accuracy: 0.4462 - val_top_k_categorical_accuracy: 0.7968 - val_top_10_accuracy: 0.8736 - val_top_30_accuracy: 0.9772 - val_top_50_accuracy: 0.9884 - val_top_100_accuracy: 0.9964
# Epoch 20/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.3175 - categorical_accuracy: 0.6372 - top_k_categorical_accuracy: 0.9602 - top_10_accuracy: 0.9921 - top_30_accuracy: 0.9999 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.3522 - val_categorical_accuracy: 0.4614 - val_top_k_categorical_accuracy: 0.7923 - val_top_10_accuracy: 0.8758 - val_top_30_accuracy: 0.9754 - val_top_50_accuracy: 0.9888 - val_top_100_accuracy: 0.9964
# Epoch 21/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.2804 - categorical_accuracy: 0.6523 - top_k_categorical_accuracy: 0.9606 - top_10_accuracy: 0.9887 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.4057 - val_categorical_accuracy: 0.4462 - val_top_k_categorical_accuracy: 0.7950 - val_top_10_accuracy: 0.8781 - val_top_30_accuracy: 0.9736 - val_top_50_accuracy: 0.9888 - val_top_100_accuracy: 0.9955
# Epoch 22/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.2608 - categorical_accuracy: 0.6540 - top_k_categorical_accuracy: 0.9652 - top_10_accuracy: 0.9913 - top_30_accuracy: 0.9999 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.4459 - val_categorical_accuracy: 0.4533 - val_top_k_categorical_accuracy: 0.7928 - val_top_10_accuracy: 0.8830 - val_top_30_accuracy: 0.9714 - val_top_50_accuracy: 0.9884 - val_top_100_accuracy: 0.9960
# Epoch 23/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.2545 - categorical_accuracy: 0.6546 - top_k_categorical_accuracy: 0.9611 - top_10_accuracy: 0.9917 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.4197 - val_categorical_accuracy: 0.4444 - val_top_k_categorical_accuracy: 0.7870 - val_top_10_accuracy: 0.8772 - val_top_30_accuracy: 0.9723 - val_top_50_accuracy: 0.9875 - val_top_100_accuracy: 0.9969
# Epoch 24/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.2279 - categorical_accuracy: 0.6616 - top_k_categorical_accuracy: 0.9643 - top_10_accuracy: 0.9915 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.4157 - val_categorical_accuracy: 0.4395 - val_top_k_categorical_accuracy: 0.7852 - val_top_10_accuracy: 0.8727 - val_top_30_accuracy: 0.9714 - val_top_50_accuracy: 0.9879 - val_top_100_accuracy: 0.9960
# Epoch 25/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.2156 - categorical_accuracy: 0.6592 - top_k_categorical_accuracy: 0.9703 - top_10_accuracy: 0.9942 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5382 - val_categorical_accuracy: 0.4529 - val_top_k_categorical_accuracy: 0.7896 - val_top_10_accuracy: 0.8781 - val_top_30_accuracy: 0.9736 - val_top_50_accuracy: 0.9884 - val_top_100_accuracy: 0.9955
# Epoch 26/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.1831 - categorical_accuracy: 0.6645 - top_k_categorical_accuracy: 0.9720 - top_10_accuracy: 0.9938 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5299 - val_categorical_accuracy: 0.4395 - val_top_k_categorical_accuracy: 0.7807 - val_top_10_accuracy: 0.8682 - val_top_30_accuracy: 0.9701 - val_top_50_accuracy: 0.9879 - val_top_100_accuracy: 0.9951
# Epoch 27/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.1737 - categorical_accuracy: 0.6736 - top_k_categorical_accuracy: 0.9762 - top_10_accuracy: 0.9957 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5646 - val_categorical_accuracy: 0.4413 - val_top_k_categorical_accuracy: 0.7896 - val_top_10_accuracy: 0.8763 - val_top_30_accuracy: 0.9719 - val_top_50_accuracy: 0.9875 - val_top_100_accuracy: 0.9964
# Epoch 28/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.1607 - categorical_accuracy: 0.6706 - top_k_categorical_accuracy: 0.9777 - top_10_accuracy: 0.9969 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5663 - val_categorical_accuracy: 0.4314 - val_top_k_categorical_accuracy: 0.7838 - val_top_10_accuracy: 0.8763 - val_top_30_accuracy: 0.9732 - val_top_50_accuracy: 0.9897 - val_top_100_accuracy: 0.9978
# Epoch 29/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.1413 - categorical_accuracy: 0.6770 - top_k_categorical_accuracy: 0.9792 - top_10_accuracy: 0.9970 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.6540 - val_categorical_accuracy: 0.4480 - val_top_k_categorical_accuracy: 0.7856 - val_top_10_accuracy: 0.8700 - val_top_30_accuracy: 0.9701 - val_top_50_accuracy: 0.9879 - val_top_100_accuracy: 0.9960
# Epoch 30/30
# 280/280 [==============================] - 10s 35ms/step - loss: 1.1111 - categorical_accuracy: 0.6823 - top_k_categorical_accuracy: 0.9781 - top_10_accuracy: 0.9971 - top_30_accuracy: 0.9999 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5825 - val_categorical_accuracy: 0.4435 - val_top_k_categorical_accuracy: 0.7865 - val_top_10_accuracy: 0.8714 - val_top_30_accuracy: 0.9741 - val_top_50_accuracy: 0.9897 - val_top_100_accuracy: 0.9964

# %%
print(hist.history)
# Out:
# {'loss': [3.134413480758667, 2.5906267166137695, 2.357630491256714, 2.19289231300354, 2.080794334411621, 1.9881305694580078, 1.9186848402023315, 1.8455028533935547, 1.7933526039123535, 1.7333534955978394], 'categorical_accuracy': [0.23908430337905884, 0.3313232958316803, 0.37945282459259033, 0.42814069986343384, 0.4643216133117676, 0.49413734674453735, 0.5170295834541321, 0.5279731750488281, 0.5419318675994873, 0.5512004494667053], 'top_k_categorical_accuracy': [0.6082635521888733, 0.7287548780441284, 0.78324955701828, 0.8125069737434387, 0.8255723118782043, 0.8372976183891296, 0.8493579030036926, 0.8623115420341492, 0.8723618388175964, 0.8820770382881165], 'top_50_accuracy': [0.9638190865516663, 0.9886097311973572, 0.9917364716529846, 0.9944165349006653, 0.9964265823364258, 0.9983249306678772, 0.9985482692718506, 0.9993299841880798, 0.9993299841880798, 0.9994416236877441], 'val_loss': [2.7855358123779297, 2.532883644104004, 2.390974283218384, 2.3102200031280518, 2.249847650527954, 2.208273410797119, 2.1725893020629883, 2.167527914047241, 2.166722297668457, 2.1751303672790527], 'val_categorical_accuracy': [0.2912014424800873, 0.3470299243927002, 0.3845466673374176, 0.4184904098510742, 0.43635550141334534, 0.4845913350582123, 0.47253239154815674, 0.4850379526615143, 0.4859312176704407, 0.47253239154815674], 'val_top_k_categorical_accuracy': [0.6694952845573425, 0.7297900915145874, 0.7664135694503784, 0.7748994827270508, 0.7891916036605835, 0.7963376641273499, 0.7981241345405579, 0.7967842817306519, 0.7985708117485046, 0.7941045165061951], 'val_top_50_accuracy': [0.9821348786354065, 0.9861545562744141, 0.9879410266876221, 0.9892809391021729, 0.9892809391021729, 0.9906207919120789, 0.9906207919120789, 0.9910674691200256, 0.9906207919120789, 0.9883876442909241]}

# %%
#Accuracy / epochs
import matplotlib.pyplot as plt
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.plot(hist.history['categorical_accuracy'], 'b--', label='top10', linewidth=2)
plt.legend
plt.show
# Out:
# 10

# %%
# Accuracy / Top K
import matplotlib.pyplot as plt
import numpy as np

k_beams = [1, 5, 10, 30, 50]
fig, ax = plt.subplots(figsize=(7,4))
y = [max(hist.history['categorical_accuracy']),
     max(hist.history['top_k_categorical_accuracy']),
     max(hist.history['top_10_accuracy']),
     max(hist.history['top_30_accuracy']),
     max(hist.history['top_50_accuracy'])]
ax.plot(k_beams,y, 'b--s', label = 'Beam selection accuracy')
ax.set(xlabel='Top K', ylabel='Accuracy')
plt.xlim(right=40)
ax.grid()
plt.legend()
plt.show()

# %%
# SSP DATA
import matplotlib.pyplot as plt
import numpy as np

k_beams = [1, 5, 10, 30, 50]
#plt.figure(figsize=(7,2.5))
fig, ax = plt.subplots(figsize=(7,4))
y_ori = [0.46097153425216675, 0.7924064993858337 ,0.8811836838722229, 0.9738693237304688, 0.9891680479049683]
y_sori = [0.4347291886806488, 0.7599106431007385, 0.8573980927467346, 0.9615857005119324, 0.9877163767814636]
y_MM_ori = [0.2361, 0.5492, 0.6675, 1.0000, 1.0000]
y_MM_sori = [0.1020, 0.3373, 0.4610, 1.0000, 1.0000]
ax.plot(k_beams,y_ori, 'b--s', label = 'Correct orientation-LIDAR')
ax.plot(k_beams,y_sori, 'k--s', label = 'Fixed oientation-LIDAR ')
ax.plot(k_beams,y_MM_ori, 'm--s', label = 'Correct orientation-MM')
ax.plot(k_beams,y_MM_sori, 'r--s', label = 'Fixed oientation-MM')
ax.set(xlabel='Top K', ylabel='Accuracy')
plt.xlim(right=40)
ax.grid()
plt.legend()
plt.show()

# %%
# Save output
fileNameIdentifier = '/content/drive/MyDrive/ssp_data/baseline_data/obstacles'
f = open(fileNameIdentifier + '.txt','w')
f.write(str(hist.history))
f.close()
