# %%
#Script context use	: This script uses Raymotime data (https://www.lasse.ufpa.br/raymobtime/) in the context of the UFPA - ITU Artificial Intelligence/Machine Learning in 5G Challenge (http://ai5gchallenge.ufpa.br/).
#Author       		: Ailton Oliveira, Aldebaro Klautau, Arthur Nascimento, Diego Gomes, Jamelly Ferreira, Walter Frazao
#Email          	: ml5gphy@gmail.com                                          
#License		: This script is distributed under "Public Domain" license.
###################################################################

#!/usr/bin/env python3
# -*- coding: utf-8 -*-

'''Trains a deep NN for choosing top-K beams
Adapted by AK: Aug 7, 2018
See
https://machinelearningmastery.com/binary-classification-tutorial-with-the-keras-deep-learning-library/
and
https://stackoverflow.com/questions/45642077/do-i-need-to-use-one-hot-encoding-if-my-output-variable-is-binary
See for explanation about convnet and filters:
https://datascience.stackexchange.com/questions/16463/what-is-are-the-default-filters-used-by-keras-convolution2d
and
http://cs231n.github.io/convolutional-networks/
'''
from google.colab import drive
drive.mount('/content/drive/')
import sys
sys.path.append('/content/drive/MyDrive/SSP_data')

import csv
import tensorflow as tf
from tensorflow.keras import metrics
from tensorflow.keras.models import model_from_json,Model
from tensorflow.keras.layers import Dense,concatenate
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.optimizers import Adadelta,Adam
from sklearn.model_selection import train_test_split
from ModelHandler import ModelHandler
import numpy as np
import argparse


###############################################################################
# Support functions
###############################################################################

#For description about top-k, including the explanation on how they treat ties (which can be misleading
#if your classifier is outputting a lot of ties (e.g. all 0's will lead to high top-k)
#https://www.tensorflow.org/api_docs/python/tf/nn/in_top_k

def top_10_accuracy(y_true,y_pred):
    return metrics.top_k_categorical_accuracy(y_true,y_pred,k=10)

def top_30_accuracy(y_true, y_pred):
    return metrics.top_k_categorical_accuracy(y_true, y_pred, k=30)

def top_50_accuracy(y_true,y_pred):
    return metrics.top_k_categorical_accuracy(y_true,y_pred,k=50)

def top_100_accuracy(y_true, y_pred):
    return metrics.top_k_categorical_accuracy(y_true, y_pred, k=100)


def sub2ind(array_shape, rows, cols):
    ind = rows*array_shape[1] + cols
    ind[ind < 0] = -1
    ind[ind >= array_shape[0]*array_shape[1]] = -1
    return ind

def ind2sub(array_shape, ind):
    ind[ind < 0] = -1
    ind[ind >= array_shape[0]*array_shape[1]] = -1
    rows = (ind.astype('int') / array_shape[1])
    cols = ind % array_shape[1]
    return (rows, cols)

def beamsLogScale(y,thresholdBelowMax):
        y_shape = y.shape
        
        for i in range(0,y_shape[0]):            
            thisOutputs = y[i,:]
            logOut = 20*np.log10(thisOutputs + 1e-30)
            minValue = np.amax(logOut) - thresholdBelowMax
            zeroedValueIndices = logOut < minValue
            thisOutputs[zeroedValueIndices]=0
            thisOutputs = thisOutputs / sum(thisOutputs)
            y[i,:] = thisOutputs
        
        return y

def getBeamOutput(output_file):
    
    thresholdBelowMax = 6
    
    print("Reading dataset...", output_file)
    output_cache_file = np.load(output_file)
    yMatrix = output_cache_file['output_classification']
    
    yMatrix = np.abs(yMatrix)
    yMatrix /= np.max(yMatrix)
    yMatrixShape = yMatrix.shape
    num_classes = yMatrix.shape[1] * yMatrix.shape[2]
    
    y = yMatrix.reshape(yMatrix.shape[0],num_classes)
    y = beamsLogScale(y,thresholdBelowMax)
    
    return y,num_classes

###############################################################################
# Data configuration
###############################################################################
tf.device('/device:GPU:0')

coord = False
img = False
lidar = True

num_epochs = 75
batch_size = 32
tgtRec = 3
seed = 7

np.random.seed(seed)

if coord == True: 
    #train
    coord_train_input_file = '/content/drive/MyDrive/ssp_data/baseline_data/coord_input/coord_input.npz'
    coord_train_cache_file = np.load(coord_train_input_file)
    X_coord = coord_train_cache_file['coordinates']
    X_coord_train, X_coord_validation = train_test_split(X_coord, test_size=0.2, random_state=seed, shuffle=True)

    coord_train_input_shape = X_coord_train.shape

if img == True:
    resizeFac = 20 # Resize Factor
    nCh = 1 # The number of channels of the image
    imgDim = (360,640) # Image dimensions
    method = 1

    #train
    img_train_input_file = '/content/drive/MyDrive/SSP_data/baseline_data/image_input/img_input_20.npz'
    img_train_cache_file = np.load(img_train_input_file)
    X_img = img_train_cache_file['inputs']
    X_img_train, X_img_validation = train_test_split(X_img, test_size=0.2, random_state=seed, shuffle=True)
    print("Reading dataset... ",img_train_input_file)

    img_train_input_shape = X_img_train.shape

if lidar == True:
    #train
    lidar_train_input_file = '/content/drive/MyDrive/SSP_data/baseline_data/lidar_input/lidar_input.npz'
    lidar_train_cache_file = np.load(lidar_train_input_file)
    X_lidar = lidar_train_cache_file['input']
    X_lidar_train, X_lidar_validation = train_test_split(X_lidar, test_size=0.2, random_state=seed, shuffle=True)
    print("Reading dataset... ",lidar_train_input_file)
    lidar_train_input_shape = X_lidar_train.shape

###############################################################################
# Output configuration
#train
output_file = '/content/drive/MyDrive/SSP_data/baseline_data/beam_output/beams_output.npz'
y_output,num_classes = getBeamOutput(output_file)
y_train, y_validation = train_test_split(y_output, test_size=0.2, random_state=seed, shuffle=True)

##############################################################################
# Model configuration
##############################################################################

#multimodal
multimodal = [coord, img, lidar]

#validationFraction = 0.2 #from 0 to 1
modelHand = ModelHandler()
opt = Adam()

if coord:
    coord_model = modelHand.createArchitecture('coord_mlp',num_classes,coord_train_input_shape[1],'complete')
if img:
    if nCh==1:   
        img_model = modelHand.createArchitecture('light_image',num_classes,[img_train_input_shape[1],img_train_input_shape[2],1],'complete')
    else:
        img_model = modelHand.createArchitecture('light_image',num_classes,[img_train_input_shape[1],img_train_input_shape[2],img_train_input_shape[3]],'complete')
if lidar:
    lidar_model = modelHand.createArchitecture('lidar_marcus',num_classes,[lidar_train_input_shape[1],lidar_train_input_shape[2],lidar_train_input_shape[3]],'complete')

if sum(multimodal) == 2:
    if coord and lidar:
        combined_model = concatenate([coord_model.output,lidar_model.output])
        z = Dense(num_classes,activation="relu")(combined_model)
        model = Model(inputs=[coord_model.input,lidar_model.input],outputs=z)
        model.compile(loss=categorical_crossentropy,
                    optimizer=opt,
                    metrics=[metrics.categorical_accuracy,
                            metrics.top_k_categorical_accuracy,
                            top_10_accuracy,
                            top_30_accuracy,
                            top_50_accuracy,
                            top_100_accuracy])
        model.summary()
        hist = model.fit([X_coord_train,X_lidar_train],y_train, 
        validation_data=([X_coord_validation, X_lidar_validation], y_validation),epochs=num_epochs,batch_size=batch_size)

    elif coord and img:
        combined_model = concatenate([coord_model.output,img_model.output])
        z = Dense(num_classes,activation="relu")(combined_model)
        model = Model(inputs=[coord_model.input,img_model.input],outputs=z)
        model.compile(loss=categorical_crossentropy,
                    optimizer=opt,
                    metrics=[metrics.categorical_accuracy,
                            metrics.top_k_categorical_accuracy,
                            top_10_accuracy,
                            top_30_accuracy,
                            top_50_accuracy,
                            top_100_accuracy])
        model.summary()
        hist = model.fit([X_coord_train,X_img_train],y_train,
        validation_data=([X_coord_validation, X_img_validation], y_validation), epochs=num_epochs,batch_size=batch_size)
    
    else:
        combined_model = concatenate([lidar_model.output,img_model.output])
        z = Dense(num_classes,activation="relu")(combined_model)
        model = Model(inputs=[lidar_model.input,img_model.input],outputs=z)
        model.compile(loss=categorical_crossentropy,
                    optimizer=opt,
                    metrics=[metrics.categorical_accuracy,
                            metrics.top_k_categorical_accuracy,
                            top_10_accuracy,
                            top_30_accuracy,
                            top_50_accuracy,
                            top_100_accuracy])
        model.summary()
        hist = model.fit([X_lidar_train,X_img_train],y_train, 
        validation_data=([X_lidar_validation, X_img_validation], y_validation), epochs=num_epochs,batch_size=batch_size)
elif sum(multimodal) == 3:
    combined_model = concatenate([lidar_model.output,img_model.output, coord_model.output])
    z = Dense(num_classes,activation="relu")(combined_model)
    model = Model(inputs=[lidar_model.input,img_model.input, coord_model.input],outputs=z)
    model.compile(loss=categorical_crossentropy,
                optimizer=opt,
                metrics=[metrics.categorical_accuracy,
                        metrics.top_k_categorical_accuracy,
                        top_10_accuracy,
                        top_30_accuracy,
                        top_50_accuracy,
                        top_100_accuracy])
    model.summary()
    hist = model.fit([X_lidar_train,X_img_train,X_coord_train],y_train,
            validation_data=([X_lidar_validation, X_img_validation, X_coord_validation], y_validation),
            epochs=num_epochs,batch_size=batch_size)

else:
    if coord:
        model = coord_model
        model.compile(loss=categorical_crossentropy,
                            optimizer=opt,
                            metrics=[metrics.categorical_accuracy,
                                    metrics.top_k_categorical_accuracy,
                                    top_10_accuracy,
                                    top_30_accuracy, 
                                    top_50_accuracy,
                                    top_100_accuracy])
        model.summary()
        hist = model.fit(X_coord_train,y_train, 
        validation_data=(X_coord_validation, y_validation),epochs=num_epochs,batch_size=batch_size)

    elif img:
        model = img_model  
        model.compile(loss=categorical_crossentropy,
                    optimizer=opt,
                    metrics=[metrics.categorical_accuracy,
                            metrics.top_k_categorical_accuracy,
                            top_10_accuracy,
                            top_30_accuracy,
                            top_50_accuracy,
                            top_100_accuracy])
        model.summary()
        hist = model.fit(X_img_train,y_train, 
        validation_data=(X_img_validation, y_validation),epochs=num_epochs,batch_size=batch_size)

    else:
        model = lidar_model
        model.compile(loss=categorical_crossentropy,
                    optimizer=opt,
                    metrics=[metrics.categorical_accuracy,
                            metrics.top_k_categorical_accuracy,
                            top_10_accuracy,
                            top_30_accuracy,
                            top_50_accuracy,
                            top_100_accuracy])
        model.summary()
        hist = model.fit(X_lidar_train,y_train,epochs=num_epochs,batch_size=batch_size, validation_data=(X_lidar_validation, y_validation))
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# Reading dataset...  /content/drive/MyDrive/SSP_data/baseline_data/lidar_input/lidar_input.npz
# Reading dataset... /content/drive/MyDrive/SSP_data/baseline_data/beam_output/beams_output.npz
# Model: "model_22"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_23 (InputLayer)        [(None, 20, 200, 10)]     0
# _________________________________________________________________
# conv2d_154 (Conv2D)          (None, 20, 200, 10)       16910
# _________________________________________________________________
# conv2d_155 (Conv2D)          (None, 20, 200, 30)       36330
# _________________________________________________________________
# conv2d_156 (Conv2D)          (None, 20, 200, 25)       60775
# _________________________________________________________________
# max_pooling2d_44 (MaxPooling (None, 10, 200, 25)       0
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 10, 200, 25)       0
# _________________________________________________________________
# conv2d_157 (Conv2D)          (None, 10, 200, 20)       24520
# _________________________________________________________________
# max_pooling2d_45 (MaxPooling (None, 10, 100, 20)       0
# _________________________________________________________________
# conv2d_158 (Conv2D)          (None, 10, 100, 15)       7515
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 10, 100, 15)       0
# _________________________________________________________________
# conv2d_159 (Conv2D)          (None, 10, 100, 10)       1360
# _________________________________________________________________
# conv2d_160 (Conv2D)          (None, 10, 100, 1)        11
# _________________________________________________________________
# flatten_22 (Flatten)         (None, 1000)              0
# _________________________________________________________________
# dense_22 (Dense)             (None, 256)               256256
# =================================================================
# Total params: 403,677
# Trainable params: 403,677
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/75
# 280/280 [==============================] - 11s 35ms/step - loss: 3.5964 - categorical_accuracy: 0.1744 - top_k_categorical_accuracy: 0.4955 - top_10_accuracy: 0.6497 - top_30_accuracy: 0.8603 - top_50_accuracy: 0.9143 - top_100_accuracy: 0.9528 - val_loss: 2.8119 - val_categorical_accuracy: 0.2921 - val_top_k_categorical_accuracy: 0.6686 - val_top_10_accuracy: 0.7990 - val_top_30_accuracy: 0.9558 - val_top_50_accuracy: 0.9795 - val_top_100_accuracy: 0.9942
# Epoch 2/75
# 280/280 [==============================] - 10s 34ms/step - loss: 2.6813 - categorical_accuracy: 0.3071 - top_k_categorical_accuracy: 0.7123 - top_10_accuracy: 0.8387 - top_30_accuracy: 0.9685 - top_50_accuracy: 0.9872 - top_100_accuracy: 0.9989 - val_loss: 2.6420 - val_categorical_accuracy: 0.3332 - val_top_k_categorical_accuracy: 0.7329 - val_top_10_accuracy: 0.8388 - val_top_30_accuracy: 0.9629 - val_top_50_accuracy: 0.9853 - val_top_100_accuracy: 0.9951
# Epoch 3/75
# 280/280 [==============================] - 10s 34ms/step - loss: 2.4227 - categorical_accuracy: 0.3704 - top_k_categorical_accuracy: 0.7674 - top_10_accuracy: 0.8751 - top_30_accuracy: 0.9755 - top_50_accuracy: 0.9923 - top_100_accuracy: 0.9996 - val_loss: 2.4123 - val_categorical_accuracy: 0.3680 - val_top_k_categorical_accuracy: 0.7633 - val_top_10_accuracy: 0.8602 - val_top_30_accuracy: 0.9687 - val_top_50_accuracy: 0.9884 - val_top_100_accuracy: 0.9969
# Epoch 4/75
# 280/280 [==============================] - 10s 35ms/step - loss: 2.2369 - categorical_accuracy: 0.4004 - top_k_categorical_accuracy: 0.8025 - top_10_accuracy: 0.8961 - top_30_accuracy: 0.9811 - top_50_accuracy: 0.9947 - top_100_accuracy: 0.9998 - val_loss: 2.3779 - val_categorical_accuracy: 0.3930 - val_top_k_categorical_accuracy: 0.7713 - val_top_10_accuracy: 0.8749 - val_top_30_accuracy: 0.9728 - val_top_50_accuracy: 0.9888 - val_top_100_accuracy: 0.9969
# Epoch 5/75
# 280/280 [==============================] - 10s 35ms/step - loss: 2.1273 - categorical_accuracy: 0.4549 - top_k_categorical_accuracy: 0.8197 - top_10_accuracy: 0.9113 - top_30_accuracy: 0.9854 - top_50_accuracy: 0.9964 - top_100_accuracy: 1.0000 - val_loss: 2.2584 - val_categorical_accuracy: 0.4502 - val_top_k_categorical_accuracy: 0.7914 - val_top_10_accuracy: 0.8781 - val_top_30_accuracy: 0.9732 - val_top_50_accuracy: 0.9888 - val_top_100_accuracy: 0.9955
# Epoch 6/75
# 280/280 [==============================] - 10s 35ms/step - loss: 1.9934 - categorical_accuracy: 0.4898 - top_k_categorical_accuracy: 0.8386 - top_10_accuracy: 0.9179 - top_30_accuracy: 0.9879 - top_50_accuracy: 0.9979 - top_100_accuracy: 1.0000 - val_loss: 2.2293 - val_categorical_accuracy: 0.4757 - val_top_k_categorical_accuracy: 0.7937 - val_top_10_accuracy: 0.8825 - val_top_30_accuracy: 0.9741 - val_top_50_accuracy: 0.9897 - val_top_100_accuracy: 0.9973
# Epoch 7/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.9305 - categorical_accuracy: 0.5052 - top_k_categorical_accuracy: 0.8494 - top_10_accuracy: 0.9267 - top_30_accuracy: 0.9924 - top_50_accuracy: 0.9995 - top_100_accuracy: 1.0000 - val_loss: 2.1932 - val_categorical_accuracy: 0.4542 - val_top_k_categorical_accuracy: 0.7937 - val_top_10_accuracy: 0.8870 - val_top_30_accuracy: 0.9745 - val_top_50_accuracy: 0.9893 - val_top_100_accuracy: 0.9960
# Epoch 8/75
# 280/280 [==============================] - 10s 35ms/step - loss: 1.8613 - categorical_accuracy: 0.5236 - top_k_categorical_accuracy: 0.8707 - top_10_accuracy: 0.9404 - top_30_accuracy: 0.9946 - top_50_accuracy: 0.9993 - top_100_accuracy: 1.0000 - val_loss: 2.1833 - val_categorical_accuracy: 0.4828 - val_top_k_categorical_accuracy: 0.8008 - val_top_10_accuracy: 0.8848 - val_top_30_accuracy: 0.9736 - val_top_50_accuracy: 0.9902 - val_top_100_accuracy: 0.9978
# Epoch 9/75
# 280/280 [==============================] - 10s 35ms/step - loss: 1.8122 - categorical_accuracy: 0.5297 - top_k_categorical_accuracy: 0.8695 - top_10_accuracy: 0.9397 - top_30_accuracy: 0.9954 - top_50_accuracy: 0.9989 - top_100_accuracy: 1.0000 - val_loss: 2.1625 - val_categorical_accuracy: 0.4846 - val_top_k_categorical_accuracy: 0.8075 - val_top_10_accuracy: 0.8915 - val_top_30_accuracy: 0.9736 - val_top_50_accuracy: 0.9902 - val_top_100_accuracy: 0.9969
# Epoch 10/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.7325 - categorical_accuracy: 0.5538 - top_k_categorical_accuracy: 0.8834 - top_10_accuracy: 0.9541 - top_30_accuracy: 0.9968 - top_50_accuracy: 0.9993 - top_100_accuracy: 1.0000 - val_loss: 2.1711 - val_categorical_accuracy: 0.4895 - val_top_k_categorical_accuracy: 0.8039 - val_top_10_accuracy: 0.8874 - val_top_30_accuracy: 0.9736 - val_top_50_accuracy: 0.9915 - val_top_100_accuracy: 0.9973
# Epoch 11/75
# 280/280 [==============================] - 10s 35ms/step - loss: 1.6759 - categorical_accuracy: 0.5683 - top_k_categorical_accuracy: 0.8946 - top_10_accuracy: 0.9584 - top_30_accuracy: 0.9986 - top_50_accuracy: 0.9998 - top_100_accuracy: 1.0000 - val_loss: 2.1678 - val_categorical_accuracy: 0.4850 - val_top_k_categorical_accuracy: 0.8039 - val_top_10_accuracy: 0.8874 - val_top_30_accuracy: 0.9714 - val_top_50_accuracy: 0.9902 - val_top_100_accuracy: 0.9973
# Epoch 12/75
# 280/280 [==============================] - 10s 35ms/step - loss: 1.6423 - categorical_accuracy: 0.5716 - top_k_categorical_accuracy: 0.8995 - top_10_accuracy: 0.9619 - top_30_accuracy: 0.9983 - top_50_accuracy: 0.9997 - top_100_accuracy: 1.0000 - val_loss: 2.1734 - val_categorical_accuracy: 0.4904 - val_top_k_categorical_accuracy: 0.8097 - val_top_10_accuracy: 0.8892 - val_top_30_accuracy: 0.9750 - val_top_50_accuracy: 0.9920 - val_top_100_accuracy: 0.9964
# Epoch 13/75
# 280/280 [==============================] - 10s 35ms/step - loss: 1.6195 - categorical_accuracy: 0.5737 - top_k_categorical_accuracy: 0.9035 - top_10_accuracy: 0.9659 - top_30_accuracy: 0.9992 - top_50_accuracy: 0.9997 - top_100_accuracy: 1.0000 - val_loss: 2.1789 - val_categorical_accuracy: 0.5011 - val_top_k_categorical_accuracy: 0.8093 - val_top_10_accuracy: 0.8897 - val_top_30_accuracy: 0.9736 - val_top_50_accuracy: 0.9897 - val_top_100_accuracy: 0.9964
# Epoch 14/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.5566 - categorical_accuracy: 0.5848 - top_k_categorical_accuracy: 0.9104 - top_10_accuracy: 0.9680 - top_30_accuracy: 0.9987 - top_50_accuracy: 0.9997 - top_100_accuracy: 1.0000 - val_loss: 2.2297 - val_categorical_accuracy: 0.4891 - val_top_k_categorical_accuracy: 0.7995 - val_top_10_accuracy: 0.8852 - val_top_30_accuracy: 0.9750 - val_top_50_accuracy: 0.9893 - val_top_100_accuracy: 0.9978
# Epoch 15/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.5229 - categorical_accuracy: 0.5947 - top_k_categorical_accuracy: 0.9222 - top_10_accuracy: 0.9712 - top_30_accuracy: 0.9991 - top_50_accuracy: 0.9999 - top_100_accuracy: 1.0000 - val_loss: 2.2022 - val_categorical_accuracy: 0.4931 - val_top_k_categorical_accuracy: 0.8017 - val_top_10_accuracy: 0.8843 - val_top_30_accuracy: 0.9728 - val_top_50_accuracy: 0.9906 - val_top_100_accuracy: 0.9964
# Epoch 16/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.4825 - categorical_accuracy: 0.6027 - top_k_categorical_accuracy: 0.9306 - top_10_accuracy: 0.9765 - top_30_accuracy: 0.9993 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.2422 - val_categorical_accuracy: 0.4573 - val_top_k_categorical_accuracy: 0.7928 - val_top_10_accuracy: 0.8776 - val_top_30_accuracy: 0.9759 - val_top_50_accuracy: 0.9888 - val_top_100_accuracy: 0.9973
# Epoch 17/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.4332 - categorical_accuracy: 0.6150 - top_k_categorical_accuracy: 0.9380 - top_10_accuracy: 0.9815 - top_30_accuracy: 0.9994 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.2330 - val_categorical_accuracy: 0.4770 - val_top_k_categorical_accuracy: 0.7963 - val_top_10_accuracy: 0.8834 - val_top_30_accuracy: 0.9759 - val_top_50_accuracy: 0.9915 - val_top_100_accuracy: 0.9960
# Epoch 18/75
# 280/280 [==============================] - 10s 35ms/step - loss: 1.4135 - categorical_accuracy: 0.6189 - top_k_categorical_accuracy: 0.9377 - top_10_accuracy: 0.9827 - top_30_accuracy: 0.9998 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.2563 - val_categorical_accuracy: 0.4623 - val_top_k_categorical_accuracy: 0.7986 - val_top_10_accuracy: 0.8763 - val_top_30_accuracy: 0.9732 - val_top_50_accuracy: 0.9902 - val_top_100_accuracy: 0.9969
# Epoch 19/75
# 280/280 [==============================] - 10s 35ms/step - loss: 1.4036 - categorical_accuracy: 0.6197 - top_k_categorical_accuracy: 0.9402 - top_10_accuracy: 0.9827 - top_30_accuracy: 0.9994 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.2869 - val_categorical_accuracy: 0.4774 - val_top_k_categorical_accuracy: 0.7954 - val_top_10_accuracy: 0.8848 - val_top_30_accuracy: 0.9705 - val_top_50_accuracy: 0.9888 - val_top_100_accuracy: 0.9969
# Epoch 20/75
# 280/280 [==============================] - 10s 35ms/step - loss: 1.3511 - categorical_accuracy: 0.6424 - top_k_categorical_accuracy: 0.9446 - top_10_accuracy: 0.9855 - top_30_accuracy: 0.9998 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.2625 - val_categorical_accuracy: 0.4685 - val_top_k_categorical_accuracy: 0.7946 - val_top_10_accuracy: 0.8736 - val_top_30_accuracy: 0.9723 - val_top_50_accuracy: 0.9897 - val_top_100_accuracy: 0.9969
# Epoch 21/75
# 280/280 [==============================] - 10s 35ms/step - loss: 1.3253 - categorical_accuracy: 0.6468 - top_k_categorical_accuracy: 0.9483 - top_10_accuracy: 0.9849 - top_30_accuracy: 0.9999 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.2990 - val_categorical_accuracy: 0.4551 - val_top_k_categorical_accuracy: 0.7896 - val_top_10_accuracy: 0.8723 - val_top_30_accuracy: 0.9741 - val_top_50_accuracy: 0.9906 - val_top_100_accuracy: 0.9964
# Epoch 22/75
# 280/280 [==============================] - 10s 35ms/step - loss: 1.3087 - categorical_accuracy: 0.6429 - top_k_categorical_accuracy: 0.9497 - top_10_accuracy: 0.9868 - top_30_accuracy: 0.9996 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.3227 - val_categorical_accuracy: 0.4636 - val_top_k_categorical_accuracy: 0.7852 - val_top_10_accuracy: 0.8785 - val_top_30_accuracy: 0.9741 - val_top_50_accuracy: 0.9911 - val_top_100_accuracy: 0.9969
# Epoch 23/75
# 280/280 [==============================] - 10s 35ms/step - loss: 1.2685 - categorical_accuracy: 0.6496 - top_k_categorical_accuracy: 0.9593 - top_10_accuracy: 0.9881 - top_30_accuracy: 0.9997 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.3210 - val_categorical_accuracy: 0.4627 - val_top_k_categorical_accuracy: 0.7892 - val_top_10_accuracy: 0.8723 - val_top_30_accuracy: 0.9736 - val_top_50_accuracy: 0.9897 - val_top_100_accuracy: 0.9973
# Epoch 24/75
# 280/280 [==============================] - 10s 35ms/step - loss: 1.2654 - categorical_accuracy: 0.6487 - top_k_categorical_accuracy: 0.9535 - top_10_accuracy: 0.9877 - top_30_accuracy: 0.9996 - top_50_accuracy: 0.9996 - top_100_accuracy: 1.0000 - val_loss: 2.3421 - val_categorical_accuracy: 0.4716 - val_top_k_categorical_accuracy: 0.7887 - val_top_10_accuracy: 0.8741 - val_top_30_accuracy: 0.9710 - val_top_50_accuracy: 0.9906 - val_top_100_accuracy: 0.9973
# Epoch 25/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.2610 - categorical_accuracy: 0.6475 - top_k_categorical_accuracy: 0.9616 - top_10_accuracy: 0.9899 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.4047 - val_categorical_accuracy: 0.4672 - val_top_k_categorical_accuracy: 0.7847 - val_top_10_accuracy: 0.8700 - val_top_30_accuracy: 0.9719 - val_top_50_accuracy: 0.9897 - val_top_100_accuracy: 0.9973
# Epoch 26/75
# 280/280 [==============================] - 10s 35ms/step - loss: 1.2086 - categorical_accuracy: 0.6621 - top_k_categorical_accuracy: 0.9640 - top_10_accuracy: 0.9912 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.3974 - val_categorical_accuracy: 0.4529 - val_top_k_categorical_accuracy: 0.7887 - val_top_10_accuracy: 0.8714 - val_top_30_accuracy: 0.9687 - val_top_50_accuracy: 0.9902 - val_top_100_accuracy: 0.9973
# Epoch 27/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.1844 - categorical_accuracy: 0.6664 - top_k_categorical_accuracy: 0.9669 - top_10_accuracy: 0.9938 - top_30_accuracy: 0.9998 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.4316 - val_categorical_accuracy: 0.4444 - val_top_k_categorical_accuracy: 0.7803 - val_top_10_accuracy: 0.8718 - val_top_30_accuracy: 0.9732 - val_top_50_accuracy: 0.9906 - val_top_100_accuracy: 0.9969
# Epoch 28/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.1475 - categorical_accuracy: 0.6727 - top_k_categorical_accuracy: 0.9729 - top_10_accuracy: 0.9937 - top_30_accuracy: 0.9995 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.3789 - val_categorical_accuracy: 0.4596 - val_top_k_categorical_accuracy: 0.7820 - val_top_10_accuracy: 0.8718 - val_top_30_accuracy: 0.9696 - val_top_50_accuracy: 0.9893 - val_top_100_accuracy: 0.9964
# Epoch 29/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.1618 - categorical_accuracy: 0.6754 - top_k_categorical_accuracy: 0.9717 - top_10_accuracy: 0.9952 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.4499 - val_categorical_accuracy: 0.4457 - val_top_k_categorical_accuracy: 0.7789 - val_top_10_accuracy: 0.8714 - val_top_30_accuracy: 0.9705 - val_top_50_accuracy: 0.9893 - val_top_100_accuracy: 0.9973
# Epoch 30/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.1538 - categorical_accuracy: 0.6761 - top_k_categorical_accuracy: 0.9727 - top_10_accuracy: 0.9935 - top_30_accuracy: 0.9999 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.4438 - val_categorical_accuracy: 0.4439 - val_top_k_categorical_accuracy: 0.7803 - val_top_10_accuracy: 0.8647 - val_top_30_accuracy: 0.9683 - val_top_50_accuracy: 0.9906 - val_top_100_accuracy: 0.9973
# Epoch 31/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.1234 - categorical_accuracy: 0.6772 - top_k_categorical_accuracy: 0.9776 - top_10_accuracy: 0.9961 - top_30_accuracy: 0.9995 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.4580 - val_categorical_accuracy: 0.4444 - val_top_k_categorical_accuracy: 0.7722 - val_top_10_accuracy: 0.8674 - val_top_30_accuracy: 0.9683 - val_top_50_accuracy: 0.9888 - val_top_100_accuracy: 0.9978
# Epoch 32/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.1194 - categorical_accuracy: 0.6787 - top_k_categorical_accuracy: 0.9812 - top_10_accuracy: 0.9963 - top_30_accuracy: 0.9997 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.4294 - val_categorical_accuracy: 0.4489 - val_top_k_categorical_accuracy: 0.7847 - val_top_10_accuracy: 0.8674 - val_top_30_accuracy: 0.9692 - val_top_50_accuracy: 0.9884 - val_top_100_accuracy: 0.9969
# Epoch 33/75
# 280/280 [==============================] - 10s 35ms/step - loss: 1.0891 - categorical_accuracy: 0.6999 - top_k_categorical_accuracy: 0.9788 - top_10_accuracy: 0.9976 - top_30_accuracy: 0.9995 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.4040 - val_categorical_accuracy: 0.4457 - val_top_k_categorical_accuracy: 0.7820 - val_top_10_accuracy: 0.8700 - val_top_30_accuracy: 0.9701 - val_top_50_accuracy: 0.9902 - val_top_100_accuracy: 0.9964
# Epoch 34/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.1068 - categorical_accuracy: 0.6833 - top_k_categorical_accuracy: 0.9767 - top_10_accuracy: 0.9949 - top_30_accuracy: 0.9998 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.4797 - val_categorical_accuracy: 0.4359 - val_top_k_categorical_accuracy: 0.7722 - val_top_10_accuracy: 0.8709 - val_top_30_accuracy: 0.9683 - val_top_50_accuracy: 0.9888 - val_top_100_accuracy: 0.9978
# Epoch 35/75
# 280/280 [==============================] - 10s 35ms/step - loss: 1.0763 - categorical_accuracy: 0.6772 - top_k_categorical_accuracy: 0.9808 - top_10_accuracy: 0.9976 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.4328 - val_categorical_accuracy: 0.4417 - val_top_k_categorical_accuracy: 0.7798 - val_top_10_accuracy: 0.8682 - val_top_30_accuracy: 0.9705 - val_top_50_accuracy: 0.9888 - val_top_100_accuracy: 0.9973
# Epoch 36/75
# 280/280 [==============================] - 10s 35ms/step - loss: 1.0610 - categorical_accuracy: 0.6947 - top_k_categorical_accuracy: 0.9814 - top_10_accuracy: 0.9974 - top_30_accuracy: 0.9998 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.4394 - val_categorical_accuracy: 0.4422 - val_top_k_categorical_accuracy: 0.7847 - val_top_10_accuracy: 0.8714 - val_top_30_accuracy: 0.9710 - val_top_50_accuracy: 0.9902 - val_top_100_accuracy: 0.9969
# Epoch 37/75
# 280/280 [==============================] - 10s 35ms/step - loss: 1.0506 - categorical_accuracy: 0.7006 - top_k_categorical_accuracy: 0.9810 - top_10_accuracy: 0.9972 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.4897 - val_categorical_accuracy: 0.4332 - val_top_k_categorical_accuracy: 0.7820 - val_top_10_accuracy: 0.8749 - val_top_30_accuracy: 0.9701 - val_top_50_accuracy: 0.9906 - val_top_100_accuracy: 0.9969
# Epoch 38/75
# 280/280 [==============================] - 10s 35ms/step - loss: 1.0522 - categorical_accuracy: 0.6916 - top_k_categorical_accuracy: 0.9859 - top_10_accuracy: 0.9972 - top_30_accuracy: 0.9997 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.4633 - val_categorical_accuracy: 0.4390 - val_top_k_categorical_accuracy: 0.7780 - val_top_10_accuracy: 0.8674 - val_top_30_accuracy: 0.9656 - val_top_50_accuracy: 0.9875 - val_top_100_accuracy: 0.9969
# Epoch 39/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.0303 - categorical_accuracy: 0.7021 - top_k_categorical_accuracy: 0.9876 - top_10_accuracy: 0.9976 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5468 - val_categorical_accuracy: 0.4542 - val_top_k_categorical_accuracy: 0.7807 - val_top_10_accuracy: 0.8678 - val_top_30_accuracy: 0.9687 - val_top_50_accuracy: 0.9902 - val_top_100_accuracy: 0.9960
# Epoch 40/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.0248 - categorical_accuracy: 0.6912 - top_k_categorical_accuracy: 0.9826 - top_10_accuracy: 0.9973 - top_30_accuracy: 0.9996 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5673 - val_categorical_accuracy: 0.4372 - val_top_k_categorical_accuracy: 0.7785 - val_top_10_accuracy: 0.8696 - val_top_30_accuracy: 0.9692 - val_top_50_accuracy: 0.9879 - val_top_100_accuracy: 0.9960
# Epoch 41/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.0252 - categorical_accuracy: 0.6967 - top_k_categorical_accuracy: 0.9853 - top_10_accuracy: 0.9970 - top_30_accuracy: 0.9999 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5437 - val_categorical_accuracy: 0.4301 - val_top_k_categorical_accuracy: 0.7838 - val_top_10_accuracy: 0.8687 - val_top_30_accuracy: 0.9714 - val_top_50_accuracy: 0.9902 - val_top_100_accuracy: 0.9973
# Epoch 42/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.0158 - categorical_accuracy: 0.6980 - top_k_categorical_accuracy: 0.9841 - top_10_accuracy: 0.9978 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.6598 - val_categorical_accuracy: 0.4502 - val_top_k_categorical_accuracy: 0.7901 - val_top_10_accuracy: 0.8736 - val_top_30_accuracy: 0.9678 - val_top_50_accuracy: 0.9888 - val_top_100_accuracy: 0.9969
# Epoch 43/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.0262 - categorical_accuracy: 0.6929 - top_k_categorical_accuracy: 0.9845 - top_10_accuracy: 0.9965 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5966 - val_categorical_accuracy: 0.4310 - val_top_k_categorical_accuracy: 0.7745 - val_top_10_accuracy: 0.8700 - val_top_30_accuracy: 0.9692 - val_top_50_accuracy: 0.9888 - val_top_100_accuracy: 0.9969
# Epoch 44/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9962 - categorical_accuracy: 0.6955 - top_k_categorical_accuracy: 0.9880 - top_10_accuracy: 0.9989 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.4958 - val_categorical_accuracy: 0.4332 - val_top_k_categorical_accuracy: 0.7776 - val_top_10_accuracy: 0.8651 - val_top_30_accuracy: 0.9701 - val_top_50_accuracy: 0.9884 - val_top_100_accuracy: 0.9973
# Epoch 45/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9939 - categorical_accuracy: 0.6958 - top_k_categorical_accuracy: 0.9902 - top_10_accuracy: 0.9989 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.6137 - val_categorical_accuracy: 0.4520 - val_top_k_categorical_accuracy: 0.7847 - val_top_10_accuracy: 0.8700 - val_top_30_accuracy: 0.9661 - val_top_50_accuracy: 0.9879 - val_top_100_accuracy: 0.9964
# Epoch 46/75
# 280/280 [==============================] - 10s 36ms/step - loss: 1.0015 - categorical_accuracy: 0.6914 - top_k_categorical_accuracy: 0.9869 - top_10_accuracy: 0.9982 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5060 - val_categorical_accuracy: 0.4364 - val_top_k_categorical_accuracy: 0.7803 - val_top_10_accuracy: 0.8589 - val_top_30_accuracy: 0.9692 - val_top_50_accuracy: 0.9875 - val_top_100_accuracy: 0.9955
# Epoch 47/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9867 - categorical_accuracy: 0.7028 - top_k_categorical_accuracy: 0.9891 - top_10_accuracy: 0.9987 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5382 - val_categorical_accuracy: 0.4448 - val_top_k_categorical_accuracy: 0.7758 - val_top_10_accuracy: 0.8669 - val_top_30_accuracy: 0.9678 - val_top_50_accuracy: 0.9897 - val_top_100_accuracy: 0.9973
# Epoch 48/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9907 - categorical_accuracy: 0.6947 - top_k_categorical_accuracy: 0.9908 - top_10_accuracy: 0.9982 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.6461 - val_categorical_accuracy: 0.4422 - val_top_k_categorical_accuracy: 0.7847 - val_top_10_accuracy: 0.8705 - val_top_30_accuracy: 0.9705 - val_top_50_accuracy: 0.9879 - val_top_100_accuracy: 0.9969
# Epoch 49/75
# 280/280 [==============================] - 10s 35ms/step - loss: 0.9821 - categorical_accuracy: 0.6873 - top_k_categorical_accuracy: 0.9903 - top_10_accuracy: 0.9991 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.4968 - val_categorical_accuracy: 0.4185 - val_top_k_categorical_accuracy: 0.7812 - val_top_10_accuracy: 0.8624 - val_top_30_accuracy: 0.9692 - val_top_50_accuracy: 0.9902 - val_top_100_accuracy: 0.9964
# Epoch 50/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9685 - categorical_accuracy: 0.7075 - top_k_categorical_accuracy: 0.9892 - top_10_accuracy: 0.9989 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.6758 - val_categorical_accuracy: 0.4364 - val_top_k_categorical_accuracy: 0.7794 - val_top_10_accuracy: 0.8718 - val_top_30_accuracy: 0.9692 - val_top_50_accuracy: 0.9906 - val_top_100_accuracy: 0.9969
# Epoch 51/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9787 - categorical_accuracy: 0.6878 - top_k_categorical_accuracy: 0.9878 - top_10_accuracy: 0.9982 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5834 - val_categorical_accuracy: 0.4359 - val_top_k_categorical_accuracy: 0.7794 - val_top_10_accuracy: 0.8682 - val_top_30_accuracy: 0.9701 - val_top_50_accuracy: 0.9888 - val_top_100_accuracy: 0.9969
# Epoch 52/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9591 - categorical_accuracy: 0.7050 - top_k_categorical_accuracy: 0.9893 - top_10_accuracy: 0.9992 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5412 - val_categorical_accuracy: 0.4314 - val_top_k_categorical_accuracy: 0.7745 - val_top_10_accuracy: 0.8656 - val_top_30_accuracy: 0.9696 - val_top_50_accuracy: 0.9884 - val_top_100_accuracy: 0.9969
# Epoch 53/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9514 - categorical_accuracy: 0.6934 - top_k_categorical_accuracy: 0.9895 - top_10_accuracy: 0.9996 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5441 - val_categorical_accuracy: 0.4364 - val_top_k_categorical_accuracy: 0.7745 - val_top_10_accuracy: 0.8593 - val_top_30_accuracy: 0.9665 - val_top_50_accuracy: 0.9893 - val_top_100_accuracy: 0.9964
# Epoch 54/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9604 - categorical_accuracy: 0.6925 - top_k_categorical_accuracy: 0.9913 - top_10_accuracy: 0.9994 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5808 - val_categorical_accuracy: 0.4364 - val_top_k_categorical_accuracy: 0.7758 - val_top_10_accuracy: 0.8700 - val_top_30_accuracy: 0.9683 - val_top_50_accuracy: 0.9897 - val_top_100_accuracy: 0.9964
# Epoch 55/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9580 - categorical_accuracy: 0.6999 - top_k_categorical_accuracy: 0.9887 - top_10_accuracy: 0.9990 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.6188 - val_categorical_accuracy: 0.4386 - val_top_k_categorical_accuracy: 0.7812 - val_top_10_accuracy: 0.8669 - val_top_30_accuracy: 0.9665 - val_top_50_accuracy: 0.9888 - val_top_100_accuracy: 0.9969
# Epoch 56/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9398 - categorical_accuracy: 0.7050 - top_k_categorical_accuracy: 0.9933 - top_10_accuracy: 0.9994 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5672 - val_categorical_accuracy: 0.4265 - val_top_k_categorical_accuracy: 0.7758 - val_top_10_accuracy: 0.8647 - val_top_30_accuracy: 0.9714 - val_top_50_accuracy: 0.9902 - val_top_100_accuracy: 0.9955
# Epoch 57/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9403 - categorical_accuracy: 0.7078 - top_k_categorical_accuracy: 0.9884 - top_10_accuracy: 0.9990 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5986 - val_categorical_accuracy: 0.4372 - val_top_k_categorical_accuracy: 0.7794 - val_top_10_accuracy: 0.8651 - val_top_30_accuracy: 0.9692 - val_top_50_accuracy: 0.9897 - val_top_100_accuracy: 0.9964
# Epoch 58/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9465 - categorical_accuracy: 0.6982 - top_k_categorical_accuracy: 0.9888 - top_10_accuracy: 0.9975 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5710 - val_categorical_accuracy: 0.4462 - val_top_k_categorical_accuracy: 0.7843 - val_top_10_accuracy: 0.8678 - val_top_30_accuracy: 0.9683 - val_top_50_accuracy: 0.9888 - val_top_100_accuracy: 0.9964
# Epoch 59/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9306 - categorical_accuracy: 0.7010 - top_k_categorical_accuracy: 0.9916 - top_10_accuracy: 0.9990 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.6393 - val_categorical_accuracy: 0.4279 - val_top_k_categorical_accuracy: 0.7803 - val_top_10_accuracy: 0.8660 - val_top_30_accuracy: 0.9656 - val_top_50_accuracy: 0.9893 - val_top_100_accuracy: 0.9969
# Epoch 60/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9268 - categorical_accuracy: 0.7113 - top_k_categorical_accuracy: 0.9929 - top_10_accuracy: 0.9994 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5879 - val_categorical_accuracy: 0.4270 - val_top_k_categorical_accuracy: 0.7713 - val_top_10_accuracy: 0.8682 - val_top_30_accuracy: 0.9705 - val_top_50_accuracy: 0.9862 - val_top_100_accuracy: 0.9973
# Epoch 61/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9293 - categorical_accuracy: 0.7049 - top_k_categorical_accuracy: 0.9928 - top_10_accuracy: 0.9991 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.6244 - val_categorical_accuracy: 0.4399 - val_top_k_categorical_accuracy: 0.7861 - val_top_10_accuracy: 0.8705 - val_top_30_accuracy: 0.9683 - val_top_50_accuracy: 0.9897 - val_top_100_accuracy: 0.9973
# Epoch 62/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9331 - categorical_accuracy: 0.7068 - top_k_categorical_accuracy: 0.9933 - top_10_accuracy: 0.9997 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5305 - val_categorical_accuracy: 0.4359 - val_top_k_categorical_accuracy: 0.7767 - val_top_10_accuracy: 0.8615 - val_top_30_accuracy: 0.9669 - val_top_50_accuracy: 0.9893 - val_top_100_accuracy: 0.9960
# Epoch 63/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9301 - categorical_accuracy: 0.6987 - top_k_categorical_accuracy: 0.9920 - top_10_accuracy: 0.9997 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5880 - val_categorical_accuracy: 0.4234 - val_top_k_categorical_accuracy: 0.7816 - val_top_10_accuracy: 0.8696 - val_top_30_accuracy: 0.9705 - val_top_50_accuracy: 0.9879 - val_top_100_accuracy: 0.9964
# Epoch 64/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9316 - categorical_accuracy: 0.7104 - top_k_categorical_accuracy: 0.9934 - top_10_accuracy: 0.9994 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5824 - val_categorical_accuracy: 0.4261 - val_top_k_categorical_accuracy: 0.7722 - val_top_10_accuracy: 0.8611 - val_top_30_accuracy: 0.9692 - val_top_50_accuracy: 0.9879 - val_top_100_accuracy: 0.9960
# Epoch 65/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9088 - categorical_accuracy: 0.6998 - top_k_categorical_accuracy: 0.9932 - top_10_accuracy: 0.9994 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.6459 - val_categorical_accuracy: 0.4207 - val_top_k_categorical_accuracy: 0.7767 - val_top_10_accuracy: 0.8660 - val_top_30_accuracy: 0.9696 - val_top_50_accuracy: 0.9897 - val_top_100_accuracy: 0.9969
# Epoch 66/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9209 - categorical_accuracy: 0.6979 - top_k_categorical_accuracy: 0.9915 - top_10_accuracy: 0.9992 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.6180 - val_categorical_accuracy: 0.4328 - val_top_k_categorical_accuracy: 0.7771 - val_top_10_accuracy: 0.8647 - val_top_30_accuracy: 0.9669 - val_top_50_accuracy: 0.9893 - val_top_100_accuracy: 0.9973
# Epoch 67/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9042 - categorical_accuracy: 0.7001 - top_k_categorical_accuracy: 0.9918 - top_10_accuracy: 0.9998 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5625 - val_categorical_accuracy: 0.4368 - val_top_k_categorical_accuracy: 0.7816 - val_top_10_accuracy: 0.8620 - val_top_30_accuracy: 0.9692 - val_top_50_accuracy: 0.9888 - val_top_100_accuracy: 0.9969
# Epoch 68/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9269 - categorical_accuracy: 0.6980 - top_k_categorical_accuracy: 0.9926 - top_10_accuracy: 0.9992 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.6248 - val_categorical_accuracy: 0.4314 - val_top_k_categorical_accuracy: 0.7798 - val_top_10_accuracy: 0.8682 - val_top_30_accuracy: 0.9661 - val_top_50_accuracy: 0.9884 - val_top_100_accuracy: 0.9964
# Epoch 69/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9079 - categorical_accuracy: 0.6995 - top_k_categorical_accuracy: 0.9926 - top_10_accuracy: 0.9996 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5490 - val_categorical_accuracy: 0.4386 - val_top_k_categorical_accuracy: 0.7852 - val_top_10_accuracy: 0.8678 - val_top_30_accuracy: 0.9678 - val_top_50_accuracy: 0.9906 - val_top_100_accuracy: 0.9973
# Epoch 70/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9059 - categorical_accuracy: 0.7092 - top_k_categorical_accuracy: 0.9902 - top_10_accuracy: 0.9996 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.6486 - val_categorical_accuracy: 0.4314 - val_top_k_categorical_accuracy: 0.7794 - val_top_10_accuracy: 0.8674 - val_top_30_accuracy: 0.9710 - val_top_50_accuracy: 0.9888 - val_top_100_accuracy: 0.9960
# Epoch 71/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.9012 - categorical_accuracy: 0.7054 - top_k_categorical_accuracy: 0.9942 - top_10_accuracy: 0.9998 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.6018 - val_categorical_accuracy: 0.4323 - val_top_k_categorical_accuracy: 0.7803 - val_top_10_accuracy: 0.8718 - val_top_30_accuracy: 0.9710 - val_top_50_accuracy: 0.9888 - val_top_100_accuracy: 0.9960
# Epoch 72/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.8991 - categorical_accuracy: 0.7014 - top_k_categorical_accuracy: 0.9936 - top_10_accuracy: 0.9996 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.6967 - val_categorical_accuracy: 0.4377 - val_top_k_categorical_accuracy: 0.7771 - val_top_10_accuracy: 0.8718 - val_top_30_accuracy: 0.9710 - val_top_50_accuracy: 0.9884 - val_top_100_accuracy: 0.9969
# Epoch 73/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.8930 - categorical_accuracy: 0.7073 - top_k_categorical_accuracy: 0.9927 - top_10_accuracy: 0.9995 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.6505 - val_categorical_accuracy: 0.4265 - val_top_k_categorical_accuracy: 0.7789 - val_top_10_accuracy: 0.8642 - val_top_30_accuracy: 0.9687 - val_top_50_accuracy: 0.9884 - val_top_100_accuracy: 0.9964
# Epoch 74/75
# 280/280 [==============================] - 10s 37ms/step - loss: 0.9085 - categorical_accuracy: 0.7035 - top_k_categorical_accuracy: 0.9940 - top_10_accuracy: 0.9996 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.5699 - val_categorical_accuracy: 0.4453 - val_top_k_categorical_accuracy: 0.7780 - val_top_10_accuracy: 0.8763 - val_top_30_accuracy: 0.9687 - val_top_50_accuracy: 0.9884 - val_top_100_accuracy: 0.9960
# Epoch 75/75
# 280/280 [==============================] - 10s 36ms/step - loss: 0.8997 - categorical_accuracy: 0.6992 - top_k_categorical_accuracy: 0.9941 - top_10_accuracy: 0.9998 - top_30_accuracy: 1.0000 - top_50_accuracy: 1.0000 - top_100_accuracy: 1.0000 - val_loss: 2.6786 - val_categorical_accuracy: 0.4283 - val_top_k_categorical_accuracy: 0.7816 - val_top_10_accuracy: 0.8660 - val_top_30_accuracy: 0.9683 - val_top_50_accuracy: 0.9884 - val_top_100_accuracy: 0.9978

# %%
#Accuracy / epochs
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(7,4))
ax.plot(hist.history['categorical_accuracy'], 'b', label = 'Categorical accuracy', linewidth=2)
ax.plot(hist.history['top_k_categorical_accuracy'], 'k--', label = 'Top 5', linewidth=2)
ax.plot(hist.history['top_10_accuracy'], 'm', label = 'Top 10', linewidth=2)
ax.plot(hist.history['top_30_accuracy'], 'g--', label = 'Top 30', linewidth=2)
ax.plot(hist.history['top_50_accuracy'], 'r', label = 'Top 50', linewidth=2)
ax.set(xlabel='Epochs', ylabel='Accuracy')
ax.grid()
plt.legend()
plt.show()

# %%
# Accuracy / Top K
import matplotlib.pyplot as plt
import numpy as np

def top_n_Rt(y_predict,valid_, N = 1):
    predict = y_predict[:,:N]
    original= valid_[:,-N:]
    rt = np.sum(1+predict) / np.sum(1+original)
    return rt

y_predict = model.predict(X_lidar_validation)
valid_ = np.sort(y_validation)

y = [max(hist.history['categorical_accuracy']),
     max(hist.history['top_k_categorical_accuracy']),
     max(hist.history['top_10_accuracy']),
     max(hist.history['top_30_accuracy']),
     max(hist.history['top_50_accuracy'])]
y_rt=[]
k_beams = [1, 5, 10, 30, 50]
for i in k_beams:
    rt = top_n_Rt(y_predict,valid_,i)
    y_rt.append(rt)
fig, ax = plt.subplots(figsize=(7,4))
ax.plot(k_beams,y_rt, 'b', label = 'Throughput ratio')
ax.plot(k_beams,y, 'r', label = 'Beam selection accuracy')
ax.set(xlabel='Top K', ylabel='Accuracy')
plt.xlim(right=51)
ax.grid()
plt.legend()
plt.show()

# %%
# Throughput ratio

def top_n_Rt(y_predict,valid_, N = 1):
    predict = y_predict[:,:N]
    original= valid_[:,-N:]
    rt = np.sum(1+predict) / np.sum(1+original)
    return rt

y_predict = model.predict(X_lidar_validation)
valid_ = np.sort(y_validation)

y=[]
k_beams = [1, 5, 10, 30, 50]
for i in k_beams:
    rt = top_n_Rt(y_predict,valid_,i)
    y.append(rt)
fig, ax = plt.subplots(figsize=(7,4))
ax.plot(k_beams,y, 'b--s', label = 'Throughput ratio')
ax.set(xlabel='Top K', ylabel='Accuracy')
plt.xlim(right=51)
ax.grid()
plt.legend()
plt.show()

# %%
# SSP DATA
import matplotlib.pyplot as plt
import numpy as np

k_beams = [1, 5, 10, 30, 50]
#plt.figure(figsize=(7,2.5))
fig, ax = plt.subplots(figsize=(7,4))
y_ori = [0.46097153425216675, 0.7924064993858337 ,0.8811836838722229, 0.9738693237304688, 0.9891680479049683]
y_sori = [0.4347291886806488, 0.7599106431007385, 0.8573980927467346, 0.9615857005119324, 0.9877163767814636]
y_MM_ori = [0.2361, 0.5492, 0.6675, 1.0000, 1.0000]
y_MM_sori = [0.1020, 0.3373, 0.4610, 1.0000, 1.0000]
ax.plot(k_beams,y_ori, 'b--s', label = 'Correct orientation-LIDAR')
ax.plot(k_beams,y_sori, 'k--s', label = 'Fixed oientation-LIDAR ')
ax.plot(k_beams,y_MM_ori, 'm--s', label = 'Correct orientation-MM')
ax.plot(k_beams,y_MM_sori, 'r--s', label = 'Fixed oientation-MM')
ax.set(xlabel='Top K', ylabel='Accuracy')
plt.xlim(right=51)
ax.grid()
plt.legend()
plt.show()

# %%
# Save output
fileNameIdentifier = '/content/drive/MyDrive/SSP_data/baseline_data/obstacles'
f = open(fileNameIdentifier + '.txt','w')
f.write(str(hist.history))
f.close()
